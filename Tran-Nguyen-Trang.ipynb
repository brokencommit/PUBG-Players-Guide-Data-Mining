# %% [markdown]
# # PUBG Death Data
# ***
#
# **Name**: Jacob Tran
#
# **Section**: (001)
# ***

# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import math
from scipy import stats
from scipy.stats import norm
# %matplotlib inline

# %% [markdown]
# ### Import Data
# ***

# %%
web_path = pd.read_excel("https://github.com/jatr6994/csci4502/blob/master/PUBG%20Death%202million.xlsx?raw=true")

##web_path_PUBG.head(50)

local_path = 'PUBG Death 2million.xlsx'
# PUBG_death = pd.read_excel(local_path)
PUBG_death = pd.read_excel(web_path)
PUBG_death.head(:10)
# Out:
#       killed_by    killer_name  killer_placement  killer_position_x  \
# 0          M249  0932313woaini               7.0           529007.7
# 1        Kar98k     arunrunrun               6.0           440414.8
# 2  Down and Out      Rabbit812               6.0           439923.2
# 3  Down and Out  0932313woaini               7.0           530312.4
# 4        SCAR-L      sa11y1126               3.0           466609.2
# 5      Bluezone            NaN               NaN                NaN
# 6  Down and Out   AT_maozaomao               7.0           529282.9
# 7          S686     ruokuisama               2.0           434772.1
# 8       Grenade        LinGend               1.0           325518.5
# 9       Falling            NaN               NaN                NaN
#
#    killer_position_y      map  \
# 0           440035.5  MIRAMAR
# 1           285918.1  MIRAMAR
# 2           282419.0  MIRAMAR
# 3           440969.0  MIRAMAR
# 4           409546.3  MIRAMAR
# ...
